# %% [markdown]
# ## Feature Exploration & Cleaning Kinsa Fever Data, US Counties

# %%
import pandas as pd
import numpy as np
import datetime as dt
import requests
import sqlite3
from sklearn.impute import SimpleImputer, MissingIndicator
from sklearn_pandas import DataFrameMapper

# %%
conn=sqlite3.connect('COVID19_county_data.db')
cursor= conn.cursor()

# %%
#Create function to query SQL data
def query_data(sql_statement):
    df=pd.read_sql(sql_statement, conn)
    #cursor.execute(sql_statement)
    return df.to_dict('records')

# %%
#Apply for access to kinsa api here to receive url instructions: https://content.kinsahealth.com/us-health-weather-map-public-api-application
def get_kinsa_data(param='US'):
    #url=f'https://{THE_URL}.com/{param}_data.json' #uncomment and replace "THE_URL" with actual kinsa api url
    response=requests.get(url)
    if response.status_code == 200:
        r_list=response.json()
        column_names=r_list['columns']
        data=r_list['data']
        df=pd.DataFrame(data, columns=column_names)
        return df
    else:
        return None

# %%
df_NY=get_kinsa_data('NY')
df_NY.head()
# Out:
#   region_id      region_name region_type state  observed_ili  atypical_ili  \
# 0     36111    Ulster County      county    NY      7.811896           NaN
# 1     36109  Tompkins County      county    NY      6.744609           NaN
# 2     36107     Tioga County      county    NY      6.962238           NaN
# 3     36105  Sullivan County      county    NY      7.168137           NaN
# 4     36103   Suffolk County      county    NY      7.219955           NaN
#
#    atypical_ili_delta  anomaly_fevers  forecast_expected  forecast_lower  \
# 0                 0.0             0.0                NaN             NaN
# 1                 0.0             0.0                NaN             NaN
# 2                 0.0             0.0                NaN             NaN
# 3                 0.0             0.0                NaN             NaN
# 4                 0.0             0.0                NaN             NaN
#
#    forecast_upper        date
# 0             NaN  2020-02-16
# 1             NaN  2020-02-16
# 2             NaN  2020-02-16
# 3             NaN  2020-02-16
# 4             NaN  2020-02-16

# %%
df_NY['region_name'].unique()
# Out:
# array(['Ulster County', 'Tompkins County', 'Tioga County',
#        'Sullivan County', 'Suffolk County', 'Steuben County',
#        'Seneca County', 'Schuyler County', 'Schoharie County',
#        'Schenectady County', 'Saratoga County', 'St. Lawrence County',
#        'Rockland County', 'Warren County', 'Washington County',
#        'Yates County', 'Wyoming County', 'Westchester County',
#        'Wayne County', 'Richmond County', 'Rensselaer County',
#        'Livingston County', 'Lewis County', 'Kings County',
#        'Jefferson County', 'Herkimer County', 'Hamilton County',
#        'Greene County', 'Genesee County', 'Fulton County',
#        'Franklin County', 'Essex County', 'Erie County',
#        'Dutchess County', 'Delaware County', 'Madison County',
#        'Monroe County', 'Queens County', 'Putnam County', 'Otsego County',
#        'Oswego County', 'Orleans County', 'Orange County',
#        'Ontario County', 'Onondaga County', 'Oneida County',
#        'Niagara County', 'New York County', 'Nassau County',
#        'Montgomery County', 'Columbia County', 'Cortland County',
#        'Clinton County', 'Chenango County', 'Chemung County',
#        'Chautauqua County', 'Cayuga County', 'Cattaraugus County',
#        'Broome County', 'Bronx County', 'Allegany County',
#        'Albany County'], dtype=object)

# %%
state_url="https://www.nrcs.usda.gov/wps/portal/nrcs/detail/national/home/?cid=nrcs143_013697"
df_fips=pd.read_html(state_url)[0]

# %%
header = df_fips.iloc[0] 
df_fips = df_fips[1:] #take the data less the header row
df_fips.columns = header
df_fips.head()
# Out:
# 0   FIPS     Name State
# 1  01001  Autauga    AL
# 2  01003  Baldwin    AL
# 3  01005  Barbour    AL
# 4  01007     Bibb    AL
# 5  01009   Blount    AL

# %%
states_list=list(df_fips['State'].unique())
states_list[:3]
# Out:
# ['AL', 'AK', 'AZ']

# %%
def compile_US_df(states_list):
    state_dicts={}
    for state in states_list:
        df=get_kinsa_data(state)
        if df is not None:
            state_dicts[state]=df
        #state_dicts.append(df)
    return state_dicts

# %%
states_df=pd.concat(compile_US_df(states_list), ignore_index=True)

# %%
states_df.head()
# Out:
#   region_id        region_name region_type state  observed_ili  atypical_ili  \
# 0     01001     Autauga County      county    AL      5.288498           NaN
# 1     01133     Winston County      county    AL      5.158465           NaN
# 2     01131      Wilcox County      county    AL      4.954751           NaN
# 3     01129  Washington County      county    AL      4.984101           NaN
# 4     01127      Walker County      county    AL      4.880931           NaN
#
#    atypical_ili_delta  anomaly_fevers  forecast_expected  forecast_lower  \
# 0                 0.0             0.0                NaN             NaN
# 1                 NaN             NaN                NaN             NaN
# 2                 NaN             NaN                NaN             NaN
# 3                 NaN             NaN                NaN             NaN
# 4                 NaN             NaN                NaN             NaN
#
#    forecast_upper        date
# 0             NaN  2020-02-16
# 1             NaN  2020-02-16
# 2             NaN  2020-02-16
# 3             NaN  2020-02-16
# 4             NaN  2020-02-16

# %%
states_df.keys()
# Out:
# Index(['region_id', 'region_name', 'region_type', 'state', 'observed_ili',
#        'atypical_ili', 'atypical_ili_delta', 'anomaly_fevers',
#        'forecast_expected', 'forecast_lower', 'forecast_upper', 'date'],
#       dtype='object')

# %%
unique_states=states_df['state'].unique()
unique_states
# Out:
# array(['AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'IA',
#        'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN',
#        'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY',
#        'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA',
#        'VT', 'WA', 'WI', 'WV', 'WY'], dtype=object)

# %%
len(unique_states)
# Out:
# 49

# %%
states_df.isna().sum()
# Out:
# region_id                  0
# region_name                0
# region_type                0
# state                      0
# observed_ili          217630
# atypical_ili          516124
# atypical_ili_delta    330252
# anomaly_fevers        330252
# forecast_expected      46635
# forecast_lower         46635
# forecast_upper         46635
# date                       0
# dtype: int64

# %%
states_df['date']=states_df['date'].apply(lambda x: pd.to_datetime(x))

# %%
states_df['date'].iloc[-1]
# Out:
# Timestamp('2020-08-07 00:00:00')

# %%
pd.to_datetime(dt.date.today())
# Out:
# Timestamp('2020-05-30 00:00:00')

# %%
states_df['date'].iloc[-1]>pd.to_datetime(dt.date.today())
# Out:
# True

# %%
future_time=states_df['date'].apply(lambda date: True if date>=pd.to_datetime(dt.date.today()) else False)

# %%
#Remove dates that correspond to future dates
states_df=states_df[~future_time]

# %%
states_df.iloc[-10:, :]
# Out:
#        region_id        region_name region_type state  observed_ili  \
# 539346     56041       Uinta County      county    WY           0.0
# 539347     56019     Johnson County      county    WY           0.0
# 539348     56037  Sweetwater County      county    WY           0.0
# 539349     56039       Teton County      county    WY           0.0
# 539350     56023     Lincoln County      county    WY           0.0
# 539351     56001      Albany County      county    WY           0.0
# 539352     56007      Carbon County      county    WY           0.0
# 539353     56009    Converse County      county    WY           0.0
# 539354     56003    Big Horn County      county    WY           0.0
# 539355     56005    Campbell County      county    WY           0.0
#
#         atypical_ili  atypical_ili_delta  anomaly_fevers  forecast_expected  \
# 539346           NaN                 NaN             NaN           0.000156
# 539347           NaN                 NaN             NaN           0.000098
# 539348           NaN                 NaN             NaN           0.000270
# 539349           NaN                 NaN             NaN           0.138593
# 539350           NaN                 NaN             NaN           0.000156
# 539351           NaN                 NaN             NaN           0.000085
# 539352           NaN                 NaN             NaN           0.000609
# 539353           NaN                 NaN             NaN           0.114620
# 539354           NaN                 NaN             NaN           0.000000
# 539355           NaN                 0.0             0.0           0.119358
#
#         forecast_lower  forecast_upper       date
# 539346             0.0        0.856408 2020-05-29
# 539347             0.0        0.834358 2020-05-29
# 539348             0.0        0.826365 2020-05-29
# 539349             0.0        0.986060 2020-05-29
# 539350             0.0        0.840003 2020-05-29
# 539351             0.0        0.831943 2020-05-29
# 539352             0.0        0.830845 2020-05-29
# 539353             0.0        0.902359 2020-05-29
# 539354             0.0        0.835832 2020-05-29
# 539355             0.0        0.933972 2020-05-29

# %%
states_df.isna().sum()
# Out:
# region_id                  0
# region_name                0
# region_type                0
# state                      0
# observed_ili               0
# atypical_ili          298494
# atypical_ili_delta    197392
# anomaly_fevers        197392
# forecast_expected      46635
# forecast_lower         46635
# forecast_upper         46635
# date                       0
# dtype: int64

# %%
states_df.dtypes
# Out:
# region_id                     object
# region_name                   object
# region_type                   object
# state                         object
# observed_ili                 float64
# atypical_ili                 float64
# atypical_ili_delta           float64
# anomaly_fevers               float64
# forecast_expected            float64
# forecast_lower               float64
# forecast_upper               float64
# date                  datetime64[ns]
# dtype: object

# %%
num_df=states_df.select_dtypes('number')

# %%
na_num_df=num_df.loc[:, num_df.isna().any().values]

# %%
na_num_df.isna().sum()
# Out:
# atypical_ili          298494
# atypical_ili_delta    197392
# anomaly_fevers        197392
# forecast_expected      46635
# forecast_lower         46635
# forecast_upper         46635
# dtype: int64

# %%
steps=[]
for col in na_num_df.columns:
    steps.append(([col], [SimpleImputer(strategy='constant', fill_value=0)]))
    steps.append(([col], [MissingIndicator()], {'alias':f'{col}_isna'}))
steps[0:4]
# Out:
# [(['atypical_ili'],
#   [SimpleImputer(add_indicator=False, copy=True, fill_value=0, missing_values=nan,
#                  strategy='constant', verbose=0)]),
#  (['atypical_ili'],
#   [MissingIndicator(error_on_new=True, features='missing-only', missing_values=nan,
#                     sparse='auto')],
#   {'alias': 'atypical_ili_isna'}),
#  (['atypical_ili_delta'],
#   [SimpleImputer(add_indicator=False, copy=True, fill_value=0, missing_values=nan,
#                  strategy='constant', verbose=0)]),
#  (['atypical_ili_delta'],
#   [MissingIndicator(error_on_new=True, features='missing-only', missing_values=nan,
#                     sparse='auto')],
#   {'alias': 'atypical_ili_delta_isna'})]

# %%
mapper=DataFrameMapper(steps, default=None, df_out=True)

# %%
cleaned_states_df=mapper.fit_transform(states_df)

# %%
cleaned_states_df.tail()
# Out:
#         atypical_ili  atypical_ili_isna  atypical_ili_delta  \
# 539351           0.0               True                 0.0
# 539352           0.0               True                 0.0
# 539353           0.0               True                 0.0
# 539354           0.0               True                 0.0
# 539355           0.0               True                 0.0
#
#         atypical_ili_delta_isna  anomaly_fevers  anomaly_fevers_isna  \
# 539351                     True             0.0                 True
# 539352                     True             0.0                 True
# 539353                     True             0.0                 True
# 539354                     True             0.0                 True
# 539355                    False             0.0                False
#
#         forecast_expected  forecast_expected_isna  forecast_lower  \
# 539351           0.000085                   False             0.0
# 539352           0.000609                   False             0.0
# 539353           0.114620                   False             0.0
# 539354           0.000000                   False             0.0
# 539355           0.119358                   False             0.0
#
#         forecast_lower_isna  forecast_upper  forecast_upper_isna region_id  \
# 539351                False        0.831943                False     56001
# 539352                False        0.830845                False     56007
# 539353                False        0.902359                False     56009
# 539354                False        0.835832                False     56003
# 539355                False        0.933972                False     56005
#
#             region_name region_type state observed_ili                 date
# 539351    Albany County      county    WY            0  2020-05-29 00:00:00
# 539352    Carbon County      county    WY            0  2020-05-29 00:00:00
# 539353  Converse County      county    WY            0  2020-05-29 00:00:00
# 539354  Big Horn County      county    WY            0  2020-05-29 00:00:00
# 539355  Campbell County      county    WY            0  2020-05-29 00:00:00

# %%
cleaned_states_df['region_name']=cleaned_states_df['region_name'].apply(lambda x: x.split(' ')[0])

# %%
cleaned_states_df.head()
# Out:
#    atypical_ili  atypical_ili_isna  atypical_ili_delta  \
# 0           0.0               True                 0.0
# 1           0.0               True                 0.0
# 2           0.0               True                 0.0
# 3           0.0               True                 0.0
# 4           0.0               True                 0.0
#
#    atypical_ili_delta_isna  anomaly_fevers  anomaly_fevers_isna  \
# 0                    False             0.0                False
# 1                     True             0.0                 True
# 2                     True             0.0                 True
# 3                     True             0.0                 True
# 4                     True             0.0                 True
#
#    forecast_expected  forecast_expected_isna  forecast_lower  \
# 0                0.0                    True             0.0
# 1                0.0                    True             0.0
# 2                0.0                    True             0.0
# 3                0.0                    True             0.0
# 4                0.0                    True             0.0
#
#    forecast_lower_isna  forecast_upper  forecast_upper_isna region_id  \
# 0                 True             0.0                 True     01001
# 1                 True             0.0                 True     01133
# 2                 True             0.0                 True     01131
# 3                 True             0.0                 True     01129
# 4                 True             0.0                 True     01127
#
#   region_name region_type state observed_ili                 date
# 0     Autauga      county    AL       5.2885  2020-02-16 00:00:00
# 1     Winston      county    AL      5.15846  2020-02-16 00:00:00
# 2      Wilcox      county    AL      4.95475  2020-02-16 00:00:00
# 3  Washington      county    AL       4.9841  2020-02-16 00:00:00
# 4      Walker      county    AL      4.88093  2020-02-16 00:00:00

# %%
cleaned_states_df.tail()
# Out:
#         atypical_ili  atypical_ili_isna  atypical_ili_delta  \
# 539351           0.0               True                 0.0
# 539352           0.0               True                 0.0
# 539353           0.0               True                 0.0
# 539354           0.0               True                 0.0
# 539355           0.0               True                 0.0
#
#         atypical_ili_delta_isna  anomaly_fevers  anomaly_fevers_isna  \
# 539351                     True             0.0                 True
# 539352                     True             0.0                 True
# 539353                     True             0.0                 True
# 539354                     True             0.0                 True
# 539355                    False             0.0                False
#
#         forecast_expected  forecast_expected_isna  forecast_lower  \
# 539351           0.000085                   False             0.0
# 539352           0.000609                   False             0.0
# 539353           0.114620                   False             0.0
# 539354           0.000000                   False             0.0
# 539355           0.119358                   False             0.0
#
#         forecast_lower_isna  forecast_upper  forecast_upper_isna region_id  \
# 539351                False        0.831943                False     56001
# 539352                False        0.830845                False     56007
# 539353                False        0.902359                False     56009
# 539354                False        0.835832                False     56003
# 539355                False        0.933972                False     56005
#
#        region_name region_type state observed_ili                 date
# 539351      Albany      county    WY            0  2020-05-29 00:00:00
# 539352      Carbon      county    WY            0  2020-05-29 00:00:00
# 539353    Converse      county    WY            0  2020-05-29 00:00:00
# 539354         Big      county    WY            0  2020-05-29 00:00:00
# 539355    Campbell      county    WY            0  2020-05-29 00:00:00

# %%
cleaned_states_df.dtypes
# Out:
# atypical_ili               float64
# atypical_ili_isna             bool
# atypical_ili_delta         float64
# atypical_ili_delta_isna       bool
# anomaly_fevers             float64
# anomaly_fevers_isna           bool
# forecast_expected          float64
# forecast_expected_isna        bool
# forecast_lower             float64
# forecast_lower_isna           bool
# forecast_upper             float64
# forecast_upper_isna           bool
# region_id                   object
# region_name                 object
# region_type                 object
# state                       object
# observed_ili                object
# date                        object
# dtype: object

# %%
cleaned_states_df.isna().sum()
# Out:
# atypical_ili               0
# atypical_ili_isna          0
# atypical_ili_delta         0
# atypical_ili_delta_isna    0
# anomaly_fevers             0
# anomaly_fevers_isna        0
# forecast_expected          0
# forecast_expected_isna     0
# forecast_lower             0
# forecast_lower_isna        0
# forecast_upper             0
# forecast_upper_isna        0
# region_id                  0
# region_name                0
# region_type                0
# state                      0
# observed_ili               0
# date                       0
# dtype: int64

# %%
cleaned_states_df['date']=cleaned_states_df['date'].astype('O')

# %%
cleaned_states_df['date']=cleaned_states_df['date'].apply(lambda x: pd.to_datetime(x))

# %%
cleaned_states_df=cleaned_states_df.rename(columns={'region_id':'FIPS'})

# %%
cleaned_states_df.head()
# Out:
#    atypical_ili  atypical_ili_isna  atypical_ili_delta  \
# 0           0.0               True                 0.0
# 1           0.0               True                 0.0
# 2           0.0               True                 0.0
# 3           0.0               True                 0.0
# 4           0.0               True                 0.0
#
#    atypical_ili_delta_isna  anomaly_fevers  anomaly_fevers_isna  \
# 0                    False             0.0                False
# 1                     True             0.0                 True
# 2                     True             0.0                 True
# 3                     True             0.0                 True
# 4                     True             0.0                 True
#
#    forecast_expected  forecast_expected_isna  forecast_lower  \
# 0                0.0                    True             0.0
# 1                0.0                    True             0.0
# 2                0.0                    True             0.0
# 3                0.0                    True             0.0
# 4                0.0                    True             0.0
#
#    forecast_lower_isna  forecast_upper  forecast_upper_isna   FIPS  \
# 0                 True             0.0                 True  01001
# 1                 True             0.0                 True  01133
# 2                 True             0.0                 True  01131
# 3                 True             0.0                 True  01129
# 4                 True             0.0                 True  01127
#
#   region_name region_type state observed_ili       date
# 0     Autauga      county    AL       5.2885 2020-02-16
# 1     Winston      county    AL      5.15846 2020-02-16
# 2      Wilcox      county    AL      4.95475 2020-02-16
# 3  Washington      county    AL       4.9841 2020-02-16
# 4      Walker      county    AL      4.88093 2020-02-16

# %%
cleaned_states_df['FIPS'] = cleaned_states_df['FIPS'].apply(lambda x: str(int(x)).zfill(5))

# %%
cleaned_states_df.to_sql('kinsa_fever', conn, index_label='id', if_exists='replace')

# %%
kinsa_df=pd.DataFrame(query_data('SELECT * FROM kinsa_fever'))

# %%
kinsa_df.tail()
# Out:
#          FIPS  anomaly_fevers  anomaly_fevers_isna  atypical_ili  \
# 323331  56001             0.0                    1           0.0
# 323332  56007             0.0                    1           0.0
# 323333  56009             0.0                    1           0.0
# 323334  56003             0.0                    1           0.0
# 323335  56005             0.0                    0           0.0
#
#         atypical_ili_delta  atypical_ili_delta_isna  atypical_ili_isna  \
# 323331                 0.0                        1                  1
# 323332                 0.0                        1                  1
# 323333                 0.0                        1                  1
# 323334                 0.0                        1                  1
# 323335                 0.0                        0                  1
#
#                        date  forecast_expected  forecast_expected_isna  \
# 323331  2020-05-29 00:00:00           0.000085                       0
# 323332  2020-05-29 00:00:00           0.000609                       0
# 323333  2020-05-29 00:00:00           0.114620                       0
# 323334  2020-05-29 00:00:00           0.000000                       0
# 323335  2020-05-29 00:00:00           0.119358                       0
#
#         forecast_lower  forecast_lower_isna  forecast_upper  \
# 323331             0.0                    0        0.831943
# 323332             0.0                    0        0.830845
# 323333             0.0                    0        0.902359
# 323334             0.0                    0        0.835832
# 323335             0.0                    0        0.933972
#
#         forecast_upper_isna      id  observed_ili region_name region_type  \
# 323331                    0  539351           0.0      Albany      county
# 323332                    0  539352           0.0      Carbon      county
# 323333                    0  539353           0.0    Converse      county
# 323334                    0  539354           0.0         Big      county
# 323335                    0  539355           0.0    Campbell      county
#
#        state
# 323331    WY
# 323332    WY
# 323333    WY
# 323334    WY
# 323335    WY
